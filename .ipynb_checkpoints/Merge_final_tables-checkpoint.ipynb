# %%
# Import packages
import os
import argparse
import time
import numpy as np
import pandas as pd
import ast
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# read csv's listing uniprotKB/AC and PDB
def get_csv(org_csv, org):
    df = pd.read_csv(org_csv, header=None, sep = ' ')
    df.columns = ['UniProtACID', 'PDB_ID']
    df['Organism'] = org
    return df

# %%
human_df = get_csv('csv_data/human_uniprot_pdb.txt', 'human')
pea_df = get_csv('csv_data/pea_uniprot_pdb.txt', 'pea')
soybean_df = get_csv('csv_data/soybean_uniprot_pdb.txt', 'soybean')
whey_df = get_csv('csv_data/whey_uniprot_pdb.txt', 'whey')
surface_df = pd.read_csv('csv_data/ply_patch_ratio_saliva.txt', header = None, sep = ',')
surface_df.columns = ['PDB_ID', 'surface_ratio']

# Further edits on surface_df to remove characters
surface_df['PDB_ID'] = surface_df.PDB_ID.str.strip('(<DirEntry >')
surface_df.PDB_ID = surface_df.PDB_ID.str.replace("'", "")
surface_df.PDB_ID = surface_df.PDB_ID.str.rstrip('.ply')
surface_df.PDB_ID = surface_df.PDB_ID.str.split('_', 1)

# %%
surface_df
# Out:
#         PDB_ID          surface_ratio
# 0    [2EAN, A]   0.15900851328402524)
# 1    [2DMH, A]   0.18465494680572278)
# 2    [2CT5, A]     0.211761748642984)
# 3    [2OEV, A]   0.15166199979291223)
# 4    [1H0Z, A]   0.16121664583057668)
# 5    [2MIO, A]   0.16128883524102144)
# 6    [6G52, A]   0.14401514976945987)
# 7    [4O6X, A]   0.18710576110131763)
# 8    [2I50, A]   0.12872469049829408)
# 9    [1A37, A]    0.1434632184953122)
# 10   [1JCN, A]   0.18243968664013485)
# 11   [5C13, A]   0.22027616871600292)
# 12   [5UZP, A]   0.21696148036888485)
# 13   [2Q8F, A]   0.22338278460147115)
# 14   [4UML, A]   0.11802282833850217)
# 15   [4N6J, A]   0.22113724976066002)
# 16   [1WOU, A]    0.0710007987436403)
# 17   [2CXY, A]   0.13465721422016882)
# 18   [2XZG, A]    0.1826005115657834)
# 19   [4DMB, A]   0.19995271918213242)
# 20   [1C8Q, A]    0.1277027593538052)
# 21   [2DBA, A]    0.1597257313697358)
# 22   [2H4V, A]   0.16352271897358736)
# 23   [6BQ1, A]   0.20205764017988667)
# 24   [1G86, A]    0.1263406956919074)
# 25   [3M0D, A]    0.1875609239433545)
# 26   [5JW7, A]   0.11579438599217892)
# 27   [3HMH, A]   0.18972216774696002)
# 28   [2K7H, A]   0.15104484124486978)
# 29   [3UVM, A]   0.12483962046001441)
# ..         ...                    ...
# 381  [4EGX, A]   0.18474382548588286)
# 382  [4CCJ, A]   0.21483133291241285)
# 383  [4YQF, B]   0.17391960427051478)
# 384  [2AW5, A]   0.09891349045323339)
# 385  [2WZB, A]    0.1380758780888561)
# 386  [4F20, A]   0.12962328369888526)
# 387  [1SS6, A]   0.18332931793395635)
# 388  [1PI2, A]   0.17058571455812854)
# 389  [2VDX, A]   0.15516285200583915)
# 390  [1YZ1, A]    0.1328338721911334)
# 391  [1PZD, A]   0.13942697727601014)
# 392  [2EBQ, A]   0.15525488549139968)
# 393  [1HZF, A]   0.16974340267223495)
# 394  [1LAR, A]   0.14820489155845007)
# 395  [3OVP, A]   0.12304981468228653)
# 396  [2KKR, A]   0.14295329005709806)
# 397  [1BBI, A]   0.21705120982488132)
# 398  [3KQ0, A]   0.16917255608265414)
# 399  [1UEZ, A]   0.17484866792751427)
# 400  [1RJB, A]   0.20950734440144878)
# 401  [3FVY, A]     0.113179312432692)
# 402  [2ALB, A]   0.14766196854228325)
# 403  [5J8H, A]   0.16016504318468872)
# 404  [2A8B, A]   0.14463581471082101)
# 405  [1P1A, A]    0.1434573539106308)
# 406  [5HDT, A]    0.1407049506093556)
# 407  [2RAI, A]    0.1840207218698514)
# 408  [3AHQ, A]     0.168186703984693)
# 409  [1AWI, A]    0.1554652958060389)
# 410  [3O7X, A]   0.18497098547342006)
#
# [411 rows x 2 columns]
